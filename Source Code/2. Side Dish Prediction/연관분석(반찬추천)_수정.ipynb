# %%
# !pip install --upgrade mlxtend
# Out:
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Collecting mlxtend
#   Downloading mlxtend-0.22.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 28.9 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.10.1)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.22.4)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.2.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (3.7.1)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from mlxtend) (67.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->mlxtend) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->mlxtend) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Installing collected packages: mlxtend
#   Attempting uninstall: mlxtend
#     Found existing installation: mlxtend 0.14.0
#     Uninstalling mlxtend-0.14.0:
#       Successfully uninstalled mlxtend-0.14.0
# Successfully installed mlxtend-0.22.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime
import os
from glob import glob
import zipfile
import shutil
import cv2
import random

import re
import zipfile
import json

from google.colab import drive

from gensim.models import Word2Vec
from gensim.models import KeyedVectors

import matplotlib.colors as mcl

from matplotlib.colors import LinearSegmentedColormap
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules, fpgrowth

# %%
# data_path = "/content/GoogleDrive/MyDrive/Colab Notebooks"
data_path = "/content/GoogleDrive/MyDrive"
ROOT_DIR = "/content"
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
drive.mount("/content/GoogleDrive/")

# shutil.copy(os.path.join(data_path,"test1801_9999.zip"), ROOT_DIR)
# shutil.copy(os.path.join(data_path,"0-301and302_400.zip"), ROOT_DIR)
# shutil.copy(os.path.join(data_path,"test 899_401.csv"), ROOT_DIR)
# shutil.copy(os.path.join(data_path,"900~1800.zip"), ROOT_DIR)
# shutil.copy(os.path.join(data_path,"test.csv"), ROOT_DIR)
# shutil.copy(os.path.join(data_path,"menu_w2v"), ROOT_DIR)
shutil.copy(os.path.join(data_path,"test_csv.csv"), ROOT_DIR)
shutil.copy(os.path.join(data_path,"include_db_menus.txt"), ROOT_DIR)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/pexpect/popen_spawn.py:60: DeprecationWarning: setDaemon() is deprecated, set the daemon attribute instead
#   self._read_thread.setDaemon(True)
# Mounted at /content/GoogleDrive/
# '/content/include_db_menus.txt'

# %%
menu_csv = pd.read_csv(os.path.join(ROOT_DIR, "test_csv.csv"), encoding="euc-kr")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(len(menu_csv))
menu_csv = menu_csv.drop_duplicates()
print(len(menu_csv))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 1912349
# 1372182

# %%
menus = []
unique_menus = []

for menu in menu_csv.menu2:
  try:
      split_list = menu.split(" ")
      fin_list = []
      for split_word in split_list:
        stop_matches = re.findall(f"[가-힣]*밥$", split_word)
        if len(stop_matches) > 0 and not ("알밥" in split_word or "볶음밥" in split_word or "덮밥" in split_word or "국밥" in split_word or "비빔밥" in split_word or "김밥" in split_word): continue
        stop_matches = re.findall(f"[가-힣]*김치$", split_word)
        if len(stop_matches) > 0: continue
        stop_matches = re.findall(f"[가-힣]*국$", split_word)
        if len(stop_matches) > 0 and not ( "해장국" in split_word): continue
        stop_matches = re.findall(f"[가-힣]*겉절이$", split_word)
        if len(stop_matches) > 0: continue
        stop_matches = re.findall(f"깍두기", split_word)
        if len(stop_matches) > 0: continue
        stop_matches = re.findall(f"과일샐러드", split_word)
        if len(stop_matches) > 0: continue
        stop_matches = re.findall(f"오이장아찌", split_word)
        if len(stop_matches) > 0: split_word = "피클"
        fin_list.append(split_word)
      if len(fin_list) >= 3:
        menus.append(fin_list)
        unique_menus.extend(fin_list)
  except:
    pass
unique_menus = list(set(unique_menus))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# for menu in menus:
#   if "안심스테이크" in " ".join(menu):
#     print(menu)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
te = TransactionEncoder()

te_ary = te.fit_transform(menus)

df = pd.DataFrame(te_ary, columns=te.columns_)

te = None
te_ary = None
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
frequent_itemsets = fpgrowth(df, min_support=1e-5, use_colnames=True)

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=1e-5)
frequent_itemsets = None
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# 반찬 추천 함수 정의
def recommend_side_dish_confidence(input_dish, top_n=10):
  str_menu = " ".join(unique_menus)
  find_matches = re.findall(f"[가-힣]*{input_dish}[가-힣]*", str_menu)

  for menu_idx, menu in enumerate(find_matches):
    print("="*50)

    if menu not in list(rules['antecedents'].str.join(',')):
      print(f"입력한 메뉴({menu})가 학습 데이터에 없습니다.")
      continue

    print(f"입력한 메뉴({menu})의 반찬은 다음과 같습니다.")
    recommended_dishes = rules[rules['antecedents'].str.join(',') == menu].sort_values('confidence', ascending=False)[:top_n]
    print(recommended_dishes['consequents'].str.join(',').tolist())

def recommend_side_dish_conviction(input_dish, top_n=10):
  str_menu = " ".join(unique_menus)
  find_matches = re.findall(f"[가-힣]*{input_dish}[가-힣]*", str_menu)

  for menu_idx, menu in enumerate(find_matches):
    print("="*50)
    print(menu)

    if menu not in list(rules['antecedents'].str.join(',')):
      print(f"입력한 메뉴({menu})가 학습 데이터에 없습니다.")
      continue

    print(f"입력한 메뉴({menu})의 반찬은 다음과 같습니다.")
    recommended_dishes = rules[rules['antecedents'].str.join(',') == menu].sort_values('conviction', ascending=False)[:top_n]
    print(recommended_dishes['consequents'].str.join(',').tolist())
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
input_dish = "치킨"
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
recommend_side_dish_confidence(input_dish)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ==================================================
# 입력한 메뉴(치킨너겟)의 반찬은 다음과 같습니다.
# ['볶음밥', '단무지', '감자탕', '우유', '떡볶이', '비빔밥', '머스타드소스', '콩나물무침', '부대찌개', '김치볶음밥']
# ==================================================
# 입력한 메뉴(매콤치킨브리또)가 학습 데이터에 없습니다.
# ==================================================
# 입력한 메뉴(치킨무)의 반찬은 다음과 같습니다.
# ['양배추샐러드', '후라이드치킨', '볶음밥', '양념치킨', '닭강정', '떡볶이', '감자튀김', '치즈볼', '우유', '부대찌개']
# ==================================================
# 입력한 메뉴(허니갈릭치킨)의 반찬은 다음과 같습니다.
# ['단무지', '치킨무', '김치볶음', '육개장']
# ==================================================
# 입력한 메뉴(치킨윙)의 반찬은 다음과 같습니다.
# ['치즈볼', '국물떡볶이', '우유', '치즈볼,국물떡볶이', '비빔밥', '볶음밥', '쌀국수', '김치찌개', '미나리무침', '국물떡볶이,미나리무침']
# ==================================================
# 입력한 메뉴(치킨피자)의 반찬은 다음과 같습니다.
# ['우유', '김치볶음밥', '비빔밥', '어묵조림', '부대찌개', '떡볶이', '김치볶음밥,어묵조림', '볶음밥', '콩나물무침', '메추리알장조림']
# ==================================================
# 입력한 메뉴(치킨시저샐러드)가 학습 데이터에 없습니다.
# ==================================================
# 입력한 메뉴(간장마늘치킨)의 반찬은 다음과 같습니다.
# ['치킨무', '단무지', '볶음밥']
# ==================================================
# 입력한 메뉴(오븐구이치킨)의 반찬은 다음과 같습니다.
# ['콩나물무침']
# ==================================================
# 입력한 메뉴(치킨텐더)의 반찬은 다음과 같습니다.
# ['양상추샐러드', '볶음밥', '단무지', '떡볶이', '비빔밥', '우유', '김치볶음밥', '부대찌개', '카레라이스', '콩나물무침']
# ==================================================
# 입력한 메뉴(베이크치킨)의 반찬은 다음과 같습니다.
# ['바나나']
# ==================================================
# 입력한 메뉴(후라이드치킨)의 반찬은 다음과 같습니다.
# ['치킨무', '양배추샐러드', '단무지', '카레라이스', '비빔밥', '볶음밥', '잔치국수', '떡볶이', '콩나물무침', '우유']
# ==================================================
# 입력한 메뉴(핫치킨브리또)의 반찬은 다음과 같습니다.
# ['김치볶음밥', '닭곰탕', '어묵볶음', '달걀장조림']
# ==================================================
# 입력한 메뉴(훈제치킨)의 반찬은 다음과 같습니다.
# ['머스타드소스', '볶음밥']
# ==================================================
# 입력한 메뉴(상하이치킨스낵랩)가 학습 데이터에 없습니다.
# ==================================================
# 입력한 메뉴(양념치킨)의 반찬은 다음과 같습니다.
# ['우유', '단무지', '볶음밥', '카레라이스', '양배추샐러드', '치킨무', '잔치국수', '비빔밥', '무생채', '치즈볼']
# ==================================================
# 입력한 메뉴(간장양념치킨)의 반찬은 다음과 같습니다.
# ['파무침', '치킨무', '우유', '바나나', '단무지', '김치볶음밥', '떡볶이', '무조림', '잔치국수', '무생채']
# ==================================================
# 입력한 메뉴(순살치킨)의 반찬은 다음과 같습니다.
# ['볶음밥', '우유', '떡볶이', '단무지', '부대찌개', '카레라이스', '비빔밥', '콩나물무침', '김치볶음밥', '양배추샐러드']
# ==================================================
# 입력한 메뉴(핫크리스피치킨)가 학습 데이터에 없습니다.
# ==================================================
# 입력한 메뉴(치킨스파게티)의 반찬은 다음과 같습니다.
# ['양상추샐러드', '볶음밥', '양송이스프', '핫도그', '요거트', '우유', '단무지무침', '함박스테이크', '딸기', '단무지']
# ==================================================
# 입력한 메뉴(치킨데리야끼)의 반찬은 다음과 같습니다.
# ['우유']
# ==================================================
# 입력한 메뉴(케이준치킨샐러드)의 반찬은 다음과 같습니다.
# ['우유', '볶음밥', '카레라이스', '단무지', '김치볶음밥', '마늘빵', '떡볶이', '부대찌개', '콩나물무침', '양송이스프']
# ==================================================
# 입력한 메뉴(치킨까스)의 반찬은 다음과 같습니다.
# ['부대찌개', '양상추샐러드', '양배추샐러드', '감자탕', '김치찌개', '우유', '볶음밥', '콩나물무침', '육개장', '떡볶이']
# ==================================================
# 입력한 메뉴(팝콘치킨)의 반찬은 다음과 같습니다.
# ['볶음밥', '떡볶이', '단무지', '김치볶음밥', '비빔밥', '우유', '양상추샐러드', '레몬에이드', '감자탕', '부대찌개']
# ==================================================
# 입력한 메뉴(치킨브리또)의 반찬은 다음과 같습니다.
# ['우유', '비빔밥', '요거트', '단무지', '오므라이스', '양상추샐러드', '볶음밥']
# ==================================================
# 입력한 메뉴(치킨바베큐)의 반찬은 다음과 같습니다.
# ['콩나물무침']
# ==================================================
# 입력한 메뉴(치킨강정)의 반찬은 다음과 같습니다.
# ['단무지', '비빔밥', '볶음밥', '우유', '카레라이스', '떡볶이', '부대찌개', '잔치국수', '바나나', '어묵볶음']
# ==================================================
# 입력한 메뉴(블랙라벨치킨)가 학습 데이터에 없습니다.
# ==================================================
# 입력한 메뉴(치킨버거)의 반찬은 다음과 같습니다.
# ['감자튀김', '우유', '콘샐러드', '우유,감자튀김', '감자튀김,콘샐러드', '치즈스틱', '레몬에이드', '오렌지주스', '김치볶음밥', '라떼']
# ==================================================
# 입력한 메뉴(로스트치킨)의 반찬은 다음과 같습니다.
# ['단무지', '카레라이스', '부대찌개', '볶음밥', '만두', '순두부찌개', '딸기', '잡채', '우유', '잔치국수']
# ==================================================
# 입력한 메뉴(치킨텐더샐러드)의 반찬은 다음과 같습니다.
# ['마늘빵', '김치볶음밥', '볶음밥', '떡볶이', '레몬에이드', '우유', '단무지', '크림스파게티', '감자탕', '단무지무침']
# ==================================================
# 입력한 메뉴(치킨텐더핫도그)가 학습 데이터에 없습니다.
# ==================================================
# 입력한 메뉴(치킨봉)의 반찬은 다음과 같습니다.
# ['비빔밥', '부대찌개', '떡볶이', '볶음우동', '김치찌개', '김치볶음밥', '라면사리', '부대찌개,라면사리', '딸기', '순두부찌개']

# %%
recommend_side_dish_conviction(input_dish)
# Out:
# ==================================================
# 치킨너겟
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 입력한 메뉴(치킨너겟)의 반찬은 다음과 같습니다.
# ['머스타드소스', '감자탕', '김치볶음밥', '무조림', '카레라이스', '허니머스타드', '김치찌개', '마파두부', '볶음우동', '콘샐러드']
# ==================================================
# 매콤치킨브리또
# 입력한 메뉴(매콤치킨브리또)가 학습 데이터에 없습니다.
# ==================================================
# 치킨무
# 입력한 메뉴(치킨무)의 반찬은 다음과 같습니다.
# ['양배추샐러드', '후라이드치킨', '양념치킨', '닭강정', '치즈볼', '순살치킨', '감자튀김', '콘샐러드', '볶음밥', '볶음밥,양배추샐러드']
# ==================================================
# 허니갈릭치킨
# 입력한 메뉴(허니갈릭치킨)의 반찬은 다음과 같습니다.
# ['치킨무', '김치볶음', '육개장', '단무지']
# ==================================================
# 치킨윙
# 입력한 메뉴(치킨윙)의 반찬은 다음과 같습니다.
# ['치즈볼', '국물떡볶이', '치즈볼,국물떡볶이', '쌀국수', '치즈볼,국물떡볶이,미나리무침', '국물떡볶이,미나리무침', '치즈볼,미나리무침', '미나리무침', '김치찌개', '비빔밥']
# ==================================================
# 치킨피자
# 입력한 메뉴(치킨피자)의 반찬은 다음과 같습니다.
# ['어묵조림', '김치볶음밥', '김치볶음밥,어묵조림', '비빔밥', '우유', '메추리알장조림', '부대찌개', '콩나물무침', '떡볶이', '볶음밥']
# ==================================================
# 치킨시저샐러드
# 입력한 메뉴(치킨시저샐러드)가 학습 데이터에 없습니다.
# ==================================================
# 간장마늘치킨
# 입력한 메뉴(간장마늘치킨)의 반찬은 다음과 같습니다.
# ['치킨무', '단무지', '볶음밥']
# ==================================================
# 오븐구이치킨
# 입력한 메뉴(오븐구이치킨)의 반찬은 다음과 같습니다.
# ['콩나물무침']
# ==================================================
# 치킨텐더
# 입력한 메뉴(치킨텐더)의 반찬은 다음과 같습니다.
# ['양상추샐러드', '머스타드소스', '김치볶음밥', '카레라이스', '마늘빵', '허니머스타드소스', '잔치국수', '미트스파게티', '크림스파게티', '허니머스타드']
# ==================================================
# 베이크치킨
# 입력한 메뉴(베이크치킨)의 반찬은 다음과 같습니다.
# ['바나나']
# ==================================================
# 후라이드치킨
# 입력한 메뉴(후라이드치킨)의 반찬은 다음과 같습니다.
# ['치킨무', '양배추샐러드', '카레라이스', '잔치국수', '김치볶음밥', '비빔밥', '오이부추무침', '치킨무,양배추샐러드', '치즈볼', '머스타드소스']
# ==================================================
# 핫치킨브리또
# 입력한 메뉴(핫치킨브리또)의 반찬은 다음과 같습니다.
# ['닭곰탕', '김치볶음밥', '달걀장조림', '어묵볶음']
# ==================================================
# 훈제치킨
# 입력한 메뉴(훈제치킨)의 반찬은 다음과 같습니다.
# ['머스타드소스', '볶음밥']
# ==================================================
# 상하이치킨스낵랩
# 입력한 메뉴(상하이치킨스낵랩)가 학습 데이터에 없습니다.
# ==================================================
# 양념치킨
# 입력한 메뉴(양념치킨)의 반찬은 다음과 같습니다.
# ['치킨무', '양배추샐러드', '카레라이스', '잔치국수', '치즈볼', '콘샐러드', '무생채', '후라이드치킨', '숙주나물무침', '콩비지찌개']
# ==================================================
# 간장양념치킨
# 입력한 메뉴(간장양념치킨)의 반찬은 다음과 같습니다.
# ['치킨무', '파무침', '꽁치조림,파무침', '꽁치조림', '라조기', '김치볶음밥', '무조림', '바나나', '복숭아', '잔치국수']
# ==================================================
# 순살치킨
# 입력한 메뉴(순살치킨)의 반찬은 다음과 같습니다.
# ['치킨무', '치즈볼', '카레라이스', '양배추샐러드', '김치볶음밥', '김치찌개', '콘샐러드', '잔치국수', '육개장', '순두부찌개']
# ==================================================
# 핫크리스피치킨
# 입력한 메뉴(핫크리스피치킨)가 학습 데이터에 없습니다.
# ==================================================
# 치킨스파게티
# 입력한 메뉴(치킨스파게티)의 반찬은 다음과 같습니다.
# ['양상추샐러드', '양송이스프', '볶음밥', '요거트', '프레즐,단무지무침,요거트', '프레즐,단무지무침', '프레즐,요거트', '프레즐', '단무지무침,요거트', '양송이스프,양상추샐러드']
# ==================================================
# 치킨데리야끼
# 입력한 메뉴(치킨데리야끼)의 반찬은 다음과 같습니다.
# ['우유']
# ==================================================
# 케이준치킨샐러드
# 입력한 메뉴(케이준치킨샐러드)의 반찬은 다음과 같습니다.
# ['카레라이스', '마늘빵', '김치볶음밥', '양송이스프', '볶음밥', '우유', '미트스파게티', '오므라이스', '레몬에이드', '크림스파게티']
# ==================================================
# 치킨까스
# 입력한 메뉴(치킨까스)의 반찬은 다음과 같습니다.
# ['양배추샐러드', '양상추샐러드', '부대찌개', '김치찌개', '카레라이스', '감자탕', '육개장', '머스타드소스', '양송이스프', '참치김치찌개']
# ==================================================
# 팝콘치킨
# 입력한 메뉴(팝콘치킨)의 반찬은 다음과 같습니다.
# ['볶음밥', '김치볶음밥', '떡볶이', '레몬에이드', '볶음밥,떡볶이', '오렌지에이드', '양상추샐러드', '오므라이스', '감자튀김', '청포도에이드']
# ==================================================
# 치킨브리또
# 입력한 메뉴(치킨브리또)의 반찬은 다음과 같습니다.
# ['요거트', '비빔밥', '오므라이스', '양상추샐러드', '우유', '볶음밥', '단무지']
# ==================================================
# 치킨바베큐
# 입력한 메뉴(치킨바베큐)의 반찬은 다음과 같습니다.
# ['콩나물무침']
# ==================================================
# 치킨강정
# 입력한 메뉴(치킨강정)의 반찬은 다음과 같습니다.
# ['카레라이스', '잔치국수', '비빔밥', '양배추샐러드', '오므라이스', '어묵볶음', '해물볶음밥', '볶음우동', '바나나', '새우볶음밥']
# ==================================================
# 블랙라벨치킨
# 입력한 메뉴(블랙라벨치킨)가 학습 데이터에 없습니다.
# ==================================================
# 치킨버거
# 입력한 메뉴(치킨버거)의 반찬은 다음과 같습니다.
# ['감자튀김', '콘샐러드', '우유', '감자튀김,콘샐러드', '우유,감자튀김', '치즈스틱', '레몬에이드', '오렌지주스', '코울슬로', '전복죽']
# ==================================================
# 로스트치킨
# 입력한 메뉴(로스트치킨)의 반찬은 다음과 같습니다.
# ['카레라이스', '하이라이스', '부대찌개', '마카롱', '딸기', '치즈볼', '순두부찌개', '비름나물무침', '생선까스,비름나물무침,만두', '생선까스,비름나물무침']
# ==================================================
# 치킨텐더샐러드
# 입력한 메뉴(치킨텐더샐러드)의 반찬은 다음과 같습니다.
# ['마늘빵', '김치볶음밥', '레몬에이드', '크림스파게티', '식빵', '마늘빵,식빵', '미트스파게티', '머스타드소스', '오므라이스', '치즈스파게티']
# ==================================================
# 치킨텐더핫도그
# 입력한 메뉴(치킨텐더핫도그)가 학습 데이터에 없습니다.
# ==================================================
# 치킨봉
# 입력한 메뉴(치킨봉)의 반찬은 다음과 같습니다.
# ['비빔밥', '부대찌개', '볶음우동', '부대찌개,라면사리', '라면사리', '치킨무', '오렌지주스', '김치찌개', '김치볶음밥', '떡볶이']

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # rules.txt 다운(추가)

# %%
rules.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   antecedents consequents  antecedent support  consequent support   support  \
# 0        (우유)      (부대찌개)            0.084816            0.045851  0.002532
# 1      (부대찌개)        (우유)            0.045851            0.084816  0.002532
# 2      (부대찌개)     (콩나물무침)            0.045851            0.053397  0.002934
# 3     (콩나물무침)      (부대찌개)            0.053397            0.045851  0.002934
# 4        (만두)      (부대찌개)            0.067860            0.045851  0.001958
#
#    confidence      lift  leverage  conviction  zhangs_metric
# 0    0.029855  0.651126 -0.001357    0.983511      -0.369267
# 1    0.055226  0.651126 -0.001357    0.968680      -0.359610
# 2    0.064000  1.198560  0.000486    1.011328       0.173626
# 3    0.054955  1.198560  0.000486    1.009634       0.175010
# 4    0.028858  0.629381 -0.001153    0.982502      -0.387154

# %%
# rules.to_csv('/content/rules.csv', encoding='utf-8', index=False)
# shutil.copy(os.path.join(ROOT_DIR,"rules.csv"), data_path)
rules.to_csv('/content/rules.csv', encoding='utf-8', index=False)
shutil.copy(os.path.join(ROOT_DIR,"rules.csv"), data_path)

# with open('/content/rules.json', 'w', encoding='utf-8') as file:
#   json.dump(rules, file)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# '/content/GoogleDrive/MyDrive/rules.csv'

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

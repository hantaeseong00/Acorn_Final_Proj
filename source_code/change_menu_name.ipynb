# %%
dict={} #  {include: [remain,..], include:[remain,..], ... }

# %%
# dict를 텍스트 파일로 저장. 파일 생성 시에는 'w', 내용 추가는 'a'
with open("../files/changed[121-240].txt", "w", encoding='utf-8') as file:
    file.write(str(dict))

# %%
# 식품영양DB 중 급식메뉴에 존재하는 음식
cat=[]
with open("../files/include_db_menus.txt", "r", encoding='utf-8') as f:
    for line in f:
        cat.append(line.split(":")[0])

# %%
# 식품영양DB에 존재하는 음식 검색
def menu(word):
    global DB_menu_list
    DB_menu_list=[]
    for menu in cat:
        if check_word(menu, word) ==True:
            DB_menu_list.append(menu)
    return DB_menu_list

# %%
# 급식메뉴 중 식품영양소DB에 없는 음식
with open('../files/remain_unique_menus.txt','r',encoding='utf-8') as file:
    data= file.read()
    data_list= data.split('\n')

# %%
# string 안에 target단어가 포함되어있으면 True 반환
def check_word(string, target):
    return target in string

# %%
# 1차 탐색. data_list 중 word가 포함되어있는 음식
def basic(word):
    global basic_list
    basic_list=[]
    for menu in data_list:
        if check_word(menu, word) ==True:
            basic_list.append(menu)
    return basic_list

# 심층 탐색. 탐색한 결과 중 word가 포함되어있는 음식
def search(basic, word):
    global search_list
    search_list=[]
    for menu in basic:
        if check_word(menu, word)== True:
            search_list.append(menu)
    return search_list

# %%
# ex1) 열무나물무침
열무= basic('열무') # 전제 급식메뉴 중 열무가 들어간 음식
len(열무)
# Out:
# 368

# %%
열무나물= search(열무,'나물') # 열무가 들어간 급식 중 나물이 들어간 음식
print(len(열무나물))
print(열무나물)
# Out:
# 39
# ['열무고추장나물', '열무두부나물', '열무된장나물', '열무나물자율', '열무나물들깨무침', '취나물열무된장무침', '열무순나물', '열무참기름나물', '열무산초나물', '솎음열무나물', '열무나물', '열무제피나물', '열무잎나물', '얼갈이열무된장나물', '열무나물장무침', '열무나물고추장무침', '솎음열무순나물', '열무솎음나물', '열무장나물', '열무비빔밥용모듬나물', '열무액젓나물', '친환경열무된장나물', '열무막장나물', '열무순나물무침', '열무솎음된장나물', '열무들깨나물', '열무비빔밥모듬나물', '솎음열무된장나물', '친환경열무쌈장나물', '열무나물들기름무침', '열무나물된장무침', '햄채열무나물', '열무고추장나물무침', '열무쌈장나물', '열무젓장나물', '열무나물비빔', '열무깨즙나물', '열무산초나물무침', '열무순된장나물']

# %%
열무무침= search(열무, '무침') # 열무가 들어간 급식 중 무침이 들어간 음식
print(len(열무무침))
열무무침
# Out:
# 100
# ['실곤약열무무침',
#  '열무쫄면무침',
#  '열무산초무침',
#  '친환경열무된장무침',
#  '열무젓장무침',
#  '열무들깨초무침',
#  '열무된장초무침',
#  '열무된장새콤무침',
#  '열무나물들깨무침',
#  '열무숙주된장무침',
#  '친환경열무무침',
#  '연근열무무침',
#  '열무홍초무침',
#  '열무액젓무침',
#  '실곤약열무김치무침',
#  '열무양념장무침',
#  '깻잎순열무무침',
#  '열무소면무침',
#  '열무들깨무침',
#  '솎음열무무침',
#  '부추열무무침',
#  '친환경열무고추장무침',
#  '솎음열무초무침',
#  '취나물열무된장무침',
#  '열무시래기들깨된장무침',
#  '열무조개살무침',
#  '열무쌈장무침',
#  '오이열무무침',
#  '열무호박된장무침',
#  '열무비빔소면무침',
#  '열무고추장매콤무침',
#  '열무된장매실청무침',
#  '열무들기름무침',
#  '열무장무침',
#  '매콤열무된장무침',
#  '열무된장무침',
#  '열무순무침',
#  '애열무된장무침',
#  '쇠고기열무무침',
#  '열무된장소스무침',
#  '두부열무무침',
#  '열무고추장된장무침',
#  '열무나물장무침',
#  '열무나물고추장무침',
#  '열무단배추무침',
#  '열무유자청무침',
#  '열무국수무침',
#  '열무맛살무침',
#  '열무얼갈이무침',
#  '애기열무무침',
#  '얼갈이열무된장무침',
#  '열무들깨된장무침',
#  '열무무침',
#  '솎음열무된장무침',
#  '솎음열무된장초무침',
#  '열무실곤약무침',
#  '열무애호박무침',
#  '열무순나물무침',
#  '열무순들깨무침',
#  '솎음열무쌈장무침',
#  '열무된장초생채무침',
#  '감말랭이열무무침',
#  '열무두부무침',
#  '열무초무침',
#  '열무숙주무침',
#  '애기열무된장무침',
#  '열무숙채된장무침',
#  '열무된장고추장무침',
#  '열무깨소금무침',
#  '열무매실무침',
# ...

# %%
열무나물무침= search(열무나물,'무침') # 열무와 나물이 들어간 급식 중 무침이 들어간 음식
print(len(열무나물무침))
열무나물무침
# Out:
# 9
# ['열무나물들깨무침',
#  '취나물열무된장무침',
#  '열무나물장무침',
#  '열무나물고추장무침',
#  '열무순나물무침',
#  '열무나물들기름무침',
#  '열무나물된장무침',
#  '열무고추장나물무침',
#  '열무산초나물무침']

# %%
cat121= list(set(열무나물+열무무침)) # set으로 중복 제거
len(cat121)
# Out:
# 130

# %%
# 겉절이, 된장, 김치
열무겉절이= search(열무,'겉절이')
열무된장= search(열무,'된장')
열무김치= search(열무,'김치')
cat121= list(set(열무나물+열무무침)-set(열무겉절이+열무된장+열무김치))
len(cat121)
# Out:
# 94

# %%
dict[cat[121]]=cat121 # dict에 추가
dict
# Out:
# {'열무나물무침': ['솎음열무순나물',
#   '열무양념무침',
#   '열무깨즙나물',
#   '열무대합살무침',
#   '쇠고기열무무침',
#   '열무참기름나물',
#   '열무두부무침',
#   '열무잎나물',
#   '열무국수무침',
#   '열무순무침',
#   '고추장열무무침',
#   '열무장나물',
#   '열무액젓나물',
#   '열무나물장무침',
#   '열무나물자율',
#   '새콤열무무침',
#   '솎음열무쌈장무침',
#   '햄채열무나물',
#   '열무순들깨무침',
#   '열무깻잎순무침',
#   '열무솎음나물',
#   '열무유자청무침',
#   '열무얼갈이무침',
#   '열무고추장나물무침',
#   '열무들깨나물',
#   '열무소면야채무침',
#   '부추열무무침',
#   '열무들깨무침',
#   '열무산초나물무침',
#   '열무나물비빔',
#   '열무장무침',
#   '열무젓장나물',
#   '열무산초무침',
#   '열무대합무침',
#   '열무들기름무침',
#   '열무깨소금무침',
#   '실곤약열무무침',
#   '열무고추장나물',
#   '솎음열무고추장무침',
#   '열무비빔밥용모듬나물',
#   '열무제피나물',
#   '열무막장나물',
#   '열무소면무침',
#   '친환경열무쌈장나물',
#   '열무숙주무침',
#   '열무나물',
#   '열무산초나물',
#   '열무들깨초무침',
#   '열무생채무침',
#   '감말랭이열무무침',
#   '연근열무무침',
#   '열무초무침',
#   '얼갈이열무무침',
#   '어린열무무침',
#   '열무애호박무침',
#   '열무홍초무침',
#   '열무순나물',
#   '열무비빔소면무침',
#   '열무실곤약무침',
#   '열무조개살무침',
#   '열무무침',
#   '친환경열무무침',
#   '솎음열무초무침',
#   '솎음열무무침',
#   '열무단배추무침',
#   '열무맛살무침',
#   '열무쌈장무침',
#   '열무나물들깨무침',
# ...

# %%
# ex2) 콩나물된장국
콩나물= basic('콩나물')
콩나물
# Out:
# ['콩나물순대해장국',
#  '소고기콩나물밥과양념장',
#  '매콤낙지콩나물볶음',
#  '친환경콩나물무채국',
#  '해물아귀살콩나물찜',
#  '맑은콩나물무국',
#  '콩나물들깨국',
#  '낙지콩나물불고기',
#  '매콤콩나물파채무침',
#  '콩나물미소국',
#  '친환경콩나물볶음',
#  '콩나물상추초무침',
#  '콩나물돈육불고기',
#  '콩나물바지락된장국',
#  '콩나물버섯밥',
#  '파채콩나물초고추장무침',
#  '콩나물하얀무침',
#  '콩나물밥과양념간장',
#  '북어콩나물두부얼큰국',
#  '얼큰콩나물라면국',
#  '콩나물깨무침',
#  '콩나물대파채무',
#  '명태콩나물조림',
#  '콩나물소면무침',
#  '콩나물근대국',
#  '콩나물무채볶음',
#  '콩나물김치북어국',
#  '콩나물양파채무침',
#  '콩나물파불고기',
#  '논우렁콩나물찜',
#  '콩나물땅콩무침',
#  '콩나물삼겹불고기',
#  '대파콩나물냉국',
#  '쭈꾸미돈육콩나물불고기',
#  '콩나물꼬시래기무침',
#  '해물두절콩나물찜',
#  '매콤아귀봉콩나물찜',
#  '실파콩나물냉국',
#  '콩나물채소무침',
#  '냉이콩나물김치된장국',
#  '콩나물매운돼지등뼈찜',
#  '콩나물새우젓국',
#  '콩나물라면찌개',
#  '매콤콩나물꼬들면',
#  '콩나물밥달래양념',
#  '콩나물무챗국국',
#  '오리훈제콩나물볶음',
#  '훈제오리콩나물겨자냉채',
#  '시금치콩나물장국',
#  '김치콩나물국물',
#  '콩나물대패제육불고기',
#  '닭콩나물볶음',
#  '아귀살콩나물찜',
#  '오징어콩나물찌개',
#  '콩나물다시마채무침',
#  '콩나물맛살채무침',
#  '콩나물베지슬라이스',
#  '돼지고기콩나물찜',
#  '콩나물스파게티',
#  '파채콩나물무침무침',
#  '콩나물대파겉절이',
#  '아귀콩나물찌개',
#  '얼큰콩나물무국',
#  '콩나물김치죽',
#  '콩나물무채맑은국',
#  '콩나물파채초',
#  '매콤콩나물찌개',
# ...

# %%
콩나물된장= search(콩나물,'된장')
콩나물된장
# Out:
# ['콩나물바지락된장국',
#  '냉이콩나물김치된장국',
#  '콩나물꽃게된장국',
#  '건미역콩나물된장무침',
#  '콩나물유부된장국',
#  '콩나물얼갈이된장국',
#  '콩나물미더덕된장국',
#  '시금치콩나물된장무침',
#  '콩나물부추된장국',
#  '버섯콩나물된장무침',
#  '콩나물무채된장국',
#  '콩나물두부된장국',
#  '콩나물팽이된장국',
#  '콩나물들깨된장국',
#  '콩나물버섯된장국']

# %%
콩나물된장국= search(콩나물된장,'국')
콩나물된장국
# Out:
# ['콩나물바지락된장국',
#  '냉이콩나물김치된장국',
#  '콩나물꽃게된장국',
#  '콩나물유부된장국',
#  '콩나물얼갈이된장국',
#  '콩나물미더덕된장국',
#  '콩나물부추된장국',
#  '콩나물무채된장국',
#  '콩나물두부된장국',
#  '콩나물팽이된장국',
#  '콩나물들깨된장국',
#  '콩나물버섯된장국']

# %%
된장= basic('된장')
된장
# Out:
# ['배추팽이된장국',
#  '유채멸치된장무침',
#  '아욱다슬기된장국',
#  '파두부된장국',
#  '된장삼겹살조림',
#  '톳나물된장무침',
#  '구운가지된장무침',
#  '매콤팽이버섯된장국',
#  '봄동된장국',
#  '아욱쇠고기된장국',
#  '된장양념두부구이',
#  '꽃게된장찜',
#  '무채들깨된장국',
#  '미소된장',
#  '유채나물된장국',
#  '돼지고기된장양념구이',
#  '콩나물바지락된장국',
#  '차돌배기된장국',
#  '감자바지락된장국',
#  '아욱들깨수제비된장국',
#  '꽃게새우된장국',
#  '빡빡된장국',
#  '콩가루얼갈이된장국',
#  '강된장쌈밥',
#  '돈육삼겹된장양념구이',
#  '나물된장무침',
#  '팽이버섯유부된장국',
#  '배추우거지된장찜',
#  '견과류된장소스',
#  '친환경열무된장무침',
#  '미역외된장국',
#  '톳나물된장초무침',
#  '우렁된장쌈',
#  '돈사태된장구이덮밥',
#  '냉이콩나물김치된장국',
#  '얼큰강된장찌게',
#  '저염돼지고기된장볶음',
#  '배추된장자작조림',
#  '공심채된장국',
#  '표고버섯순두부된장국',
#  '강된장호박잎쌈',
#  '미소어묵된장국',
#  '오렌지된장드레싱',
#  '깨순된장무침',
#  '고추양파된장박이',
#  '팽이버섯파된장국',
#  '두부미더덕된장국',
#  '고구마줄기된장국',
#  '시래기바지락된장국',
#  '된장짜글이',
#  '팽이버섯두부쌀된장국',
#  '된장무채국',
#  '늙은호박얼큰된장국',
#  '오만디두부된장국',
#  '유부팽이버섯된장국',
#  '얼갈이된장무침',
#  '달래두부된장국',
#  '강된장우렁쌈밥',
#  '참나물된장나물',
#  '단배추바지락된장국',
#  '아삭고추마늘된장무침',
#  '팽이버섯어묵된장국',
#  '청량초된장국찌개',
#  '북어된장국',
#  '명란순두부된장국',
#  '두부야채된장국',
#  '미소된장드레싱',
#  '아욱고추장된장무침',
# ...

# %%
된장국= search(된장,'국')
된장국
# Out:
# ['배추팽이된장국',
#  '아욱다슬기된장국',
#  '파두부된장국',
#  '매콤팽이버섯된장국',
#  '봄동된장국',
#  '아욱쇠고기된장국',
#  '무채들깨된장국',
#  '유채나물된장국',
#  '콩나물바지락된장국',
#  '차돌배기된장국',
#  '감자바지락된장국',
#  '아욱들깨수제비된장국',
#  '꽃게새우된장국',
#  '빡빡된장국',
#  '콩가루얼갈이된장국',
#  '팽이버섯유부된장국',
#  '미역외된장국',
#  '냉이콩나물김치된장국',
#  '공심채된장국',
#  '표고버섯순두부된장국',
#  '미소어묵된장국',
#  '팽이버섯파된장국',
#  '두부미더덕된장국',
#  '고구마줄기된장국',
#  '시래기바지락된장국',
#  '팽이버섯두부쌀된장국',
#  '된장무채국',
#  '늙은호박얼큰된장국',
#  '오만디두부된장국',
#  '유부팽이버섯된장국',
#  '달래두부된장국',
#  '단배추바지락된장국',
#  '팽이버섯어묵된장국',
#  '청량초된장국찌개',
#  '북어된장국',
#  '명란순두부된장국',
#  '두부야채된장국',
#  '된장배추국',
#  '팽이맑은된장국',
#  '근대올갱이된장국',
#  '무청들깨된장국',
#  '두부애호박바지락살된장국',
#  '유부백된장국',
#  '한우된장국',
#  '우렁호박된장국',
#  '친환경팽이두부된장국',
#  '미더덕두부된장국',
#  '저염다슬기된장국',
#  '아욱들깨된장국',
#  '무유부된장국',
#  '무채김치된장국',
#  '배추속대된장국',
#  '무청된장국',
#  '새송이두부된장국',
#  '동치미된장국',
#  '아욱된장옹심이국',
#  '바지락팽이된장국',
#  '쑥봄동된장국',
#  '매콤두부팽이된장국',
#  '홍게살된장국',
#  '갯가재된장국',
#  '근대채소된장국',
#  '겨울초된장국',
#  '두된장국',
#  '아욱취나물된장국',
#  '아욱조갯살된장국',
#  '우거지얼갈이된장국',
#  '조갯살호박된장국',
#  '배추조개된장국',
# ...

# %%
cat134= list(set(콩나물된장국))
dict[cat[134]]= cat134
dict
# Out:
# {'열무나물무침': ['솎음열무순나물',
#   '열무양념무침',
#   '열무깨즙나물',
#   '열무대합살무침',
#   '쇠고기열무무침',
#   '열무참기름나물',
#   '열무두부무침',
#   '열무잎나물',
#   '열무국수무침',
#   '열무순무침',
#   '고추장열무무침',
#   '열무장나물',
#   '열무액젓나물',
#   '열무나물장무침',
#   '열무나물자율',
#   '새콤열무무침',
#   '솎음열무쌈장무침',
#   '햄채열무나물',
#   '열무순들깨무침',
#   '열무깻잎순무침',
#   '열무솎음나물',
#   '열무유자청무침',
#   '열무얼갈이무침',
#   '열무고추장나물무침',
#   '열무들깨나물',
#   '열무소면야채무침',
#   '부추열무무침',
#   '열무들깨무침',
#   '열무산초나물무침',
#   '열무나물비빔',
#   '열무장무침',
#   '열무젓장나물',
#   '열무산초무침',
#   '열무대합무침',
#   '열무들기름무침',
#   '열무깨소금무침',
#   '실곤약열무무침',
#   '열무고추장나물',
#   '솎음열무고추장무침',
#   '열무비빔밥용모듬나물',
#   '열무제피나물',
#   '열무막장나물',
#   '열무소면무침',
#   '친환경열무쌈장나물',
#   '열무숙주무침',
#   '열무나물',
#   '열무산초나물',
#   '열무들깨초무침',
#   '열무생채무침',
#   '감말랭이열무무침',
#   '연근열무무침',
#   '열무초무침',
#   '얼갈이열무무침',
#   '어린열무무침',
#   '열무애호박무침',
#   '열무홍초무침',
#   '열무순나물',
#   '열무비빔소면무침',
#   '열무실곤약무침',
#   '열무조개살무침',
#   '열무무침',
#   '친환경열무무침',
#   '솎음열무초무침',
#   '솎음열무무침',
#   '열무단배추무침',
#   '열무맛살무침',
#   '열무쌈장무침',
#   '열무나물들깨무침',
# ...

# %%
len(cat134)
# Out:
# 12

# %%
dict.keys()
# Out:
# dict_keys(['열무나물무침', '콩나물된장국'])

# %%
cat[122]
menu('숙주')
# Out:
# ['숙주나물무침']

# %%
숙주= basic('숙주')
print(len(숙주))
print(숙주)
# Out:
# 1064
# ...

# %%
숙주나물= search(숙주,'나물')
len(숙주나물)
# Out:
# 183

# %%
숙주무침= search(숙주,'무침')
숙주무침
# Out:
# ['숙주나물크래미무침',
#  '단배추숙주무침',
#  '숙주오이산초무침',
#  '숙주파채무침',
#  '숙주장아찌무침',
#  '숙주유부무침',
#  '숙주당근두부무침',
#  '숙주오이들깨무침',
#  '무숙주무침',
#  '숙주취나물무침',
#  '숙주나물유채무침',
#  '숙주무채무침',
#  '숙주오이무침',
#  '숙주겨자채무침',
#  '숙주게살무침',
#  '간장무채숙주무침',
#  '숙주초고추장무침',
#  '숙주무짠지무침',
#  '어묵숙주무침',
#  '오이숙주초무침',
#  '숙주나물맛살겨자무침',
#  '숙주홍초무침',
#  '청포묵쇠고기숙주무침',
#  '숙주나물맛살무침',
#  '숙주부추들깨무침',
#  '꼬들간장무채곤약숙주무침',
#  '숙주채소무침',
#  '숙주느타리무침',
#  '숙주크레미무침',
#  '열무숙주된장무침',
#  '숙주참치무침',
#  '동부묵숙주김가루무침',
#  '숙주무무침',
#  '훈제순살숙주무침',
#  '꽃맛살숙주겨자무침',
#  '숙주나물매콤무침',
#  '청포묵채숙주무침',
#  '숙주팽이버섯무침',
#  '숙주나물베이컨무침',
#  '숙주유부겨자무침',
#  '숙주맛살겨자초무침',
#  '브로콜리숙주무침',
#  '숙주간장무채무침',
#  '숙주올방개묵무침',
#  '숙주부추겨자무침',
#  '오이숙주맛살초무침',
#  '짜사이숙주무침',
#  '게맛살숙주무침',
#  '맛살숙주겨자무침',
#  '숙주청경채나물무침',
#  '숙주나물겨자채무침',
#  '숙주쑥갓들깨무침',
#  '숙주크래미나물무침',
#  '숙주들깨가루무침',
#  '숙주무침나물',
#  '숙주맛살와사비무침',
#  '숙주파프리카무침',
#  '숙주삼색무침',
#  '꼬들무채장아찌숙주무침',
#  '계란두부숙주무침',
#  '숙주야채무침',
#  '숙주나물들깨무침',
#  '찹쌀꿔바로우숙주무침',
#  '숙주간장단무지채무침',
#  '느타리버섯숙주무침',
#  '숙주맛살무침',
#  '숙주크랩무침',
# ...

# %%
cat122= list(set(숙주나물+숙주무침))
len(cat122)
# Out:
# 404

# %%
dict[cat[122]]=cat122
dict.keys()
# Out:
# dict_keys(['열무나물무침', '콩나물된장국', '숙주나물무침'])

# %%
cat[123]
menu('비름')
# Out:
# ['비름나물무침']

# %%
비름=basic('비름')

# %%
비름나물= search(비름,'나물')
비름무침= search(비름,'무침')

# %%
cat123= list(set(비름나물+비름무침))
dict[cat[123]]= cat123
dict[cat[123
        
        ]]
# Out:
# ['비름나물된장국',
#  '두부비름무침',
#  '비름고추장나물',
#  '비름나물초무침',
#  '비름나물볶음',
#  '참비름무침',
#  '비름나물',
#  '비름나물유자무침',
#  '비름나물된장무침',
#  '참비름나물된장무침',
#  '비름나물고추장무침',
#  '비름된장나물',
#  '비름쌈장나물',
#  '비름나물두부무침',
#  '고추장비름나물',
#  '비름숙채무침',
#  '참비름고추장무침',
#  '비름된장나물무침',
#  '참비름고추장나물',
#  '비름나물장무침',
#  '비름고추장무침',
#  '비름나초무침',
#  '비름나물새콤무침',
#  '비름초무침',
#  '비름나물참깨무침',
#  '참비름된장무침',
#  '비름나물숙채',
#  '비름나물초고추장무침',
#  '참비름나물',
#  '비름나물초장무침',
#  '비름장무침',
#  '비름나물전',
#  '비름나물깨무침',
#  '비름무침',
#  '비름나물쌈장무침',
#  '비름된장무침',
#  '친환경비름나물고추장무침',
#  '비름나물숙채무침']

# %%
cat[124]
# Out:
# '배추나물무침'

# %%
배추= basic('배추')
배추나물= search(배추, '나물')
배추무침= search(배추, '무침')
cat124= list(set(배추나물+배추무침))
dict[cat[124]]= cat124
dict[cat[124]] 
# '양배추','콩나물배추맑은국'
# Out:
# ['중화풍배추나물',
#  '솎음배추된장무침',
#  '오이양배추피클무침',
#  '양배추콩가루무침',
#  '알배기배추숙주나물',
#  '오이양배추고추장무침',
#  '아기배추나물',
#  '애배추겉절이나물',
#  '배추나물밥',
#  '부추양배추고추장무침',
#  '납작만두양배추무침',
#  '양배추청경채나물',
#  '양배추초고추장무침',
#  '통배추나물',
#  '양배추참깨소스무침',
#  '얼갈이배추나물쌈',
#  '훈제오리양배추소스무침',
#  '단배추숙주나물',
#  '콩나물배추맑은국',
#  '단배추초장무침',
#  '얼갈이배추무침',
#  '두부배추무침',
#  '알배기배추무침',
#  '배추속된장무침',
#  '진미포양배추무침',
#  '양배추일미무침',
#  '풋배추무침',
#  '속배추된장무침',
#  '양배추초장무침',
#  '양배추오이초무침',
#  '데친양배추쌈장무침',
#  '양배추머스터드무침',
#  '양배추비빔무침',
#  '양배추오이액젓무침',
#  '세발나물배추무침',
#  '연배추된장무침',
#  '양배추깨소스무침',
#  '양배추배머스터드무침',
#  '일미양배추무침',
#  '양배추사과무침',
#  '새콤달콤양배추무침',
#  '양배추검은깨소스무침',
#  '비건진미채양배추무침',
#  '양배추진미채무침',
#  '배추청국장무침',
#  '들깨두부단배추나물',
#  '꼬막살단배추무침',
#  '배추나물된장무침',
#  '오이양배추유자무침',
#  '양배추겨자초무침',
#  '얼갈이배추된장나물',
#  '배추나물볶음',
#  '양배추치커리유자무침',
#  '콩나물고사리배추무',
#  '사과양배추겨자무침',
#  '단배추무생채무침',
#  '양배추간장초무침',
#  '단배추참나물겉절이',
#  '애기배추된장무침',
#  '양배추기름나물',
#  '단배추오이무침',
#  '양배추깻잎생채나물',
#  '호배추무침',
#  '봄동배추무침',
#  '배추얼갈이된장나물',
#  '홍진미양배추무침',
#  '배추숙회나물',
# ...

# %%
len(cat124)
# Out:
# 398

# %%
양배추= basic('양배추')
국= basic('국')
양배추
# Out:
# ['삶은양배추',
#  '양배추파채초무침',
#  '양배추사과샐러드',
#  '비트양배추피클',
#  '양배추',
#  '양배추오징어초무침',
#  '양배추쌈숙쌈',
#  '양배추마요샐럿',
#  '오리훈제양배추볶음',
#  '양배추숙채무침',
#  '양배추계란국',
#  '양배추찜호박잎쌈',
#  '양배추샐러',
#  '오이적양배추무침',
#  '양배추캐비지롤',
#  '대패돼지고기양배추볶음',
#  '구프랑햄양배추볶음',
#  '양배추고추장',
#  '쇠고기아기양배추볶음',
#  '양배추베이컨부침',
#  '친환경양배추생채',
#  '수육양배추쌈',
#  '양배추쌈추쌈',
#  '양배추옥수수콘볶음',
#  '어묵양배추볶음',
#  '진미채양배추초무침',
#  '양배추케첩마요샐러드',
#  '양배추들깨소스샐러드',
#  '양배추아몬드샐러드',
#  '사과양배추건포도사라다',
#  '양배추부추겨자채',
#  '바싹불고기양배추드레싱',
#  '양배추고추장무침',
#  '근대양배추찜',
#  '양배추인삼무침',
#  '과일양배추콘슬로우',
#  '양배추우렁강된장쌈',
#  '양배추옛날샐러드',
#  '계란양배추샌드위치',
#  '양배추간장샐러드',
#  '양배추사라다빵',
#  '다시마양배추쌈',
#  '진미포양배추무침',
#  '양배추파채샐러드',
#  '오이고추양배추쌈',
#  '깻잎양배추호박잎쌈',
#  '양배추브로콜리초장',
#  '쌈양배추',
#  '모둠양배추피클',
#  '양배추브로콜리초회',
#  '양파양배추장아찌',
#  '양배추콘키위샐러드',
#  '양배추초샐러드',
#  '양배추사과요거트샐러드',
#  '양배추콘드레싱',
#  '일미채양배추매콤무침',
#  '양배추오리엔탈드레싱',
#  '찐양배추쌈',
#  '양배추망고샐러드',
#  '쇠고기양배추볶음',
#  '우렁이양배추무침',
#  '양배추깻잎찜쌈',
#  '양배추냉채소스무',
#  '미니양배추구이',
#  '부추양배추볶음',
#  '양배추케요샐러드',
#  '양배추피자',
# ...

# %%
cat124= list(set(배추나물+배추무침)-set(양배추+국))
len(cat124)
# Out:
# 206

# %%
dict[cat[124]]= cat124
dict[cat[124]]
# Out:
# ['삶은배추무침',
#  '단배추들깨소스무침',
#  '중화풍배추나물',
#  '솎음배추된장무침',
#  '단배추막장나물',
#  '배추무침나물',
#  '애기배추들깨무침',
#  '알배기배추숙주나물',
#  '봄동배추나물',
#  '속배추시금치나물',
#  '배추김삼색나물',
#  '배추청경채무침',
#  '아기배추나물',
#  '애배추겉절이나물',
#  '배추나물밥',
#  '쌈배추나물',
#  '배추어묵채무침',
#  '배추김치무침',
#  '알배추무침',
#  '배추나물',
#  '머구단배추나물',
#  '통배추나물',
#  '데친배추무침',
#  '삶은배추쌈장무침',
#  '배추속대된장무침',
#  '알배추무무침',
#  '참나물알배추무침',
#  '배추고추장무침',
#  '배추베이컨무침',
#  '애기배추무침',
#  '통배추된장나물',
#  '알배기배추나물',
#  '얼갈이배추나물쌈',
#  '배추겉절이나물',
#  '단배추치커리무침',
#  '솎음배추사과무침',
#  '부추배추무침',
#  '단배추숙주나물',
#  '도토리묵단배추무침',
#  '알배추된장무침',
#  '알배추나물',
#  '단배추초장무침',
#  '얼갈이배추무침',
#  '속배추두부무침',
#  '두부배추무침',
#  '단배추매실된장무침',
#  '배추무침',
#  '알배기배추무침',
#  '솎음배추나물',
#  '들깨배추나물',
#  '달래쌈배추무침',
#  '배추속된장무침',
#  '참나물단배추무침',
#  '쌈배추참깨무침',
#  '솎음배추된장나물',
#  '배추생김치무침',
#  '쌈배추된장나물',
#  '알배추오이무침',
#  '호배추된장무침',
#  '도토리묵알배추무침',
#  '풋배추무침',
#  '단배추깨소금나물',
#  '속배추된장무침',
#  '청방배추무침',
#  '묵배추무침',
#  '솎음단배추무침',
#  '단배추돌나물초무침',
#  '알배추들깨나물',
#  '숙주단배추무침',
#  '애배추된장무침',
#  '단배추연된장무침',
# ...

# %%
cat[125]
menu('방풍')
# Out:
# ['방풍나물무침']

# %%
방풍= basic('방풍')
방풍나물= search(방풍,'나물')
방풍무침= search(방풍,'무침')
set(방풍나물+방풍무침)
# Out:
# {'갯방풍고추장나물',
#  '갯방풍나물',
#  '건방풍나물볶음',
#  '건방풍무침',
#  '무친방풍나물',
#  '방풍고추장나물',
#  '방풍고추장무침',
#  '방풍나물',
#  '방풍나물겉절이',
#  '방풍나물고추장무침',
#  '방풍나물된장무침',
#  '방풍나물두부무침',
#  '방풍나물들기름무침',
#  '방풍나물들기름볶음',
#  '방풍나물들깨볶음',
#  '방풍나물무겉절이',
#  '방풍나물밥',
#  '방풍나물볶음',
#  '방풍나물새콤무침',
#  '방풍나물스프',
#  '방풍나물쌈장무침',
#  '방풍나물유자청샐러드',
#  '방풍나물장무침',
#  '방풍나물장아찌',
#  '방풍나물전',
#  '방풍나물절임',
#  '방풍나물초고추장무침',
#  '방풍나물초무침',
#  '방풍나물초장무침',
#  '방풍나물튀김',
#  '방풍된장나물',
#  '방풍된장나물무침',
#  '방풍된장무침',
#  '방풍들기름나물볶음',
#  '방풍무침',
#  '방풍쌈배추무침',
#  '방풍오이무침',
#  '방풍잎초무침',
#  '방풍초고추장무침',
#  '방풍초나물',
#  '방풍초무침',
#  '방풍초참나물초무침',
#  '방풍취나물무침',
#  '삼겹살방풍나물볶음',
#  '생방풍나물',
#  '애느타리방풍나물',
#  '오렌지방풍나물샐러드',
#  '오징어방풍나물초무침',
#  '오징어방풍초무침',
#  '제철방풍나물',
#  '취나물방풍나물',
#  '친환경방풍나물',
#  '친환경해방풍나물초무침',
#  '해방풍나물',
#  '해방풍초무침',
#  '홍합방풍나물'}

# %%
basic('방풍나물')
# Out:
# ['취나물방풍나물',
#  '친환경방풍나물',
#  '삼겹살방풍나물볶음',
#  '방풍나물유자청샐러드',
#  '무친방풍나물',
#  '방풍나물밥',
#  '방풍나물장아찌',
#  '홍합방풍나물',
#  '방풍나물무겉절이',
#  '방풍나물스프',
#  '방풍나물장무침',
#  '방풍나물두부무침',
#  '방풍나물들기름무침',
#  '방풍나물새콤무침',
#  '오렌지방풍나물샐러드',
#  '친환경해방풍나물초무침',
#  '생방풍나물',
#  '갯방풍나물',
#  '방풍나물초장무침',
#  '건방풍나물볶음',
#  '방풍나물겉절이',
#  '방풍나물절임',
#  '방풍나물쌈장무침',
#  '방풍나물초고추장무침',
#  '방풍나물초무침',
#  '오징어방풍나물초무침',
#  '해방풍나물',
#  '애느타리방풍나물',
#  '방풍나물볶음',
#  '방풍나물고추장무침',
#  '방풍나물',
#  '제철방풍나물',
#  '방풍나물들깨볶음',
#  '방풍나물튀김',
#  '방풍나물들기름볶음',
#  '방풍나물된장무침',
#  '방풍나물전']

# %%
# 전, 장아찌, 스프, 절임, 튀김
방풍전= search(방풍,'전')
방풍장아찌= search(방풍, '장아찌')
방풍스프= search(방풍, '스프')
방풍절임= search(방풍, '절임')
방풍튀김= search(방풍, '튀김')
방풍밥= search(방풍, '밥')

# %%
cat125= set(방풍나물+방풍무침)-set(방풍전+방풍장아찌+방풍스프+방풍절임+방풍튀김+방풍밥)
dict[cat[125]]= cat125
len(cat125)
# Out:
# 50

# %%
cat[126]
# Out:
# '냉이나물무침'

# %%
냉이= basic('냉이')
냉이나물= search(냉이,'나물')
냉이무침= search(냉이,'무침')
냉이겉절이= search(냉이,'겉절이')

# %%
set(냉이나물+냉이무침+냉이겉절이)
# Out:
# {'냉이갑오징어초무침',
#  '냉이고막살무침',
#  '냉이고추장나물무침',
#  '냉이고추장무침',
#  '냉이김치콩나물얼큰국',
#  '냉이나물',
#  '냉이나물된장무침',
#  '냉이달래된장무침',
#  '냉이동초된장무침',
#  '냉이된장고추장무침',
#  '냉이된장나물',
#  '냉이된장나물무침',
#  '냉이된장무침',
#  '냉이두부무침',
#  '냉이무침',
#  '냉이바지락살된장무침',
#  '냉이봄동나물',
#  '냉이봄동무침',
#  '냉이시금치고추장무침',
#  '냉이시금치나물',
#  '냉이시금치무침',
#  '냉이쌈장무침',
#  '냉이장무침',
#  '냉이조갯살무침',
#  '냉이주꾸미초무침',
#  '냉이죽순무침',
#  '냉이초고추장무침',
#  '냉이초무침',
#  '냉이콩가루무침',
#  '냉이콩나물김치된장국',
#  '냉이콩나물장국',
#  '달래냉이나물',
#  '달래냉이무침',
#  '봄동냉이겉절이',
#  '봄동냉이나물',
#  '봄동냉이무침',
#  '섬초냉이고추장무침',
#  '숙주냉이나물',
#  '시금치냉이무침',
#  '양배추고추냉이무침',
#  '양파고추냉이무침',
#  '양파부추고추냉이무침',
#  '얼갈이배추냉이무침',
#  '오이냉이무침',
#  '친환경냉이된장무침',
#  '콩나물냉이',
#  '콩나물냉이국'}

# %%
# 국
냉이국= search(냉이,'국')
cat126= list(set(냉이나물+냉이무침+냉이겉절이)-set(냉이국))
dict[cat[126]]= cat126
dict[cat[126]]
# Out:
# ['양배추고추냉이무침',
#  '냉이바지락살된장무침',
#  '봄동냉이무침',
#  '친환경냉이된장무침',
#  '섬초냉이고추장무침',
#  '냉이된장나물',
#  '달래냉이무침',
#  '냉이된장고추장무침',
#  '냉이고추장나물무침',
#  '냉이초무침',
#  '양파고추냉이무침',
#  '냉이시금치무침',
#  '냉이죽순무침',
#  '냉이시금치나물',
#  '얼갈이배추냉이무침',
#  '냉이두부무침',
#  '냉이시금치고추장무침',
#  '콩나물냉이',
#  '냉이장무침',
#  '냉이고막살무침',
#  '냉이나물',
#  '냉이조갯살무침',
#  '냉이갑오징어초무침',
#  '냉이고추장무침',
#  '냉이콩가루무침',
#  '오이냉이무침',
#  '냉이동초된장무침',
#  '냉이된장무침',
#  '봄동냉이겉절이',
#  '시금치냉이무침',
#  '양파부추고추냉이무침',
#  '냉이봄동무침',
#  '냉이초고추장무침',
#  '봄동냉이나물',
#  '냉이나물된장무침',
#  '냉이쌈장무침',
#  '냉이봄동나물',
#  '냉이주꾸미초무침',
#  '달래냉이나물',
#  '냉이달래된장무침',
#  '숙주냉이나물',
#  '냉이된장나물무침',
#  '냉이무침']

# %%
cat[127]
# Out:
# '깻잎나물무침'

# %%
깻잎= basic('깻잎')
깻잎나물= search(깻잎,'나물')
깻잎무침= search(깻잎, '무침')
cat127= list(set(깻잎나물+깻잎무침))
dict[cat[127]]= cat127

# %%
cat[128]
# Out:
# ['건취나물볶', '건취나물된장국', '건취나물나물', '건취볶음', '건취나물볶음', '건취나물들깨볶음', '건취', '건취나물밥']

# %%
건취= basic('건취')
건취나물= search(건취,'나물')
건취무침= search(건취,'무침')
cat128= 건취나물+건취무침
cat128
# Out:
# ['건취나물볶', '건취나물된장국', '건취나물나물', '건취나물볶음', '건취나물들깨볶음', '건취나물밥']

# %%
건취밥= search(건취,'밥')
건취국= search(건취,'국')
cat128= list(set(건취나물+건취무침)-set(건취밥+건취국))
dict[cat[128]]= cat128
cat128
# Out:
# ['건취나물나물', '건취나물볶음', '건취나물들깨볶음', '건취나물볶']

# %%
cat[129]
# Out:
# '가지나물무침'

# %%
가지= basic('가지')
가지나물= search(가지,'나물')
가지무침= search(가지,'무침')
가지밥= search(가지,'밥')
가지국= search(가지,'국')
cat129= list(set(가지나물+가지무침)-set(가지밥+가지국))
dict[cat[129]]= cat129
cat129
# Out:
# ['가지꽈리무침',
#  '애호박가지무침',
#  '중화가지나물',
#  '구운가지굴소스무침',
#  '파프리카가지나물',
#  '호박가지구이무침',
#  '가지구이된장무침',
#  '가지양념장무침',
#  '가지들깨무침',
#  '가지초무침',
#  '가지허브구이무침',
#  '두반장가지나물',
#  '어향가지나물볶음',
#  '가지구이양념무침',
#  '꽈리고추가지나물',
#  '가지꽈리고추무침',
#  '튀긴가지무침',
#  '담백가지나물',
#  '가지나물',
#  '구운가지애호박무침',
#  '가지나물침',
#  '가지된장무침',
#  '가지숙주무침',
#  '가지무침',
#  '건가지나물볶음',
#  '가지호박나물',
#  '들깨가지나물',
#  '가지액젓무침',
#  '중화풍가지나물',
#  '가지나물소고기볶음',
#  '두가지나물',
#  '굴소스가지나물볶음',
#  '간장가지나물볶음',
#  '구운가지땅콩무침',
#  '가지새우나물',
#  '양념가지무침',
#  '꽈리고추가지찜무침',
#  '구운가지양념무침',
#  '구운가지야채무침',
#  '가지찜무침',
#  '매콤생가지무침',
#  '허브가지무침',
#  '가지굴소스나물',
#  '시골표가지나물',
#  '팽이가지나물',
#  '청양가지나물',
#  '세가지나물',
#  '가지들기름무침',
#  '가지애호박구이무침',
#  '새송이가지나물',
#  '매콤가지나물',
#  '가지부추된장무침',
#  '가지오븐구이무침',
#  '가지찜양념장무침',
#  '쇠고기가지나물',
#  '가지중화풍나물',
#  '가지찜양념무침',
#  '찐가지나물',
#  '구운가지양념장무침',
#  '부추가지나물',
#  '매콤가지무침',
#  '가지청경채나물',
#  '찐가지무침',
#  '양념꼬들가지무침',
#  '가지된장소스무침',
#  '구운버섯가지나물',
#  '굴소스가지나물',
#  '허브가지구이무침',
#  '가지구이나물',
#  '가지청양고추무침',
#  '가지쌈장무침',
# ...

# %%
cat[130]
# Out:
# '가죽나물무침'

# %%
menu('가죽')
# Out:
# ['가죽나물무침']

# %%
가죽= basic('가죽')
가죽나물= search(가죽,'나물')
cat130= 가죽나물
dict[cat[130]]= cat130

# %%
cat[131]
# Out:
# '돌나물물김치'

# %%
돌나물= basic('돌나물')
돌나물겉절이= search(돌나물,'겉절이')
cat131= 돌나물겉절이
dict[cat[131]]= cat131

# %%
cat[132]
# Out:
# '고들빼기김치'

# %%
dict[cat[132]]=None

# %%
cat[133]
# Out:
# '호박잎된장국'

# %%
menu('된장국')
# Out:
# ['무시래기된장국',
#  '호박잎된장국',
#  '콩나물된장국',
#  '우거지된장국',
#  '애호박된장국',
#  '시금치된장국',
#  '시래기된장국',
#  '해물된장국',
#  '아욱된장국',
#  '배추된장국',
#  '미역된장국',
#  '냉이된장국',
#  '근대된장국',
#  '감자된장국',
#  '우렁된장국',
#  '미소된장국',
#  '쑥된장국',
#  '무된장국']

# %%
호박잎= basic('호박잎')
호박잎된장= search(호박잎,'된장')
호박잎쌈= search(호박잎,'쌈')
호박잎무침= search(호박잎,'무침')
cat133=list(set(호박잎된장)-set(호박잎쌈+ 호박잎무침))
dict[cat[133]]= cat133

# %%
cat[134]
# Out:
# '콩나물된장국'

# %%
된장국= basic('된장국')
콩나물된장국= search(된장국,'콩나물')
cat134=콩나물된장국
dict[cat[134]]= cat134

# %%
cat[135]
# Out:
# '우거지된장국'

# %%
우거지된장국= search(된장국,'우거지')
cat135= 우거지된장국
dict[cat[135]]= cat135

# %%
cat[136]
# Out:
# '얼갈이배춧국'

# %%
배춧국= basic('배춧국')
된장국얼갈이= search(된장국,'얼갈이')

# %%
배추국= basic('배추국')
배추국얼갈이= search(배추국, '얼갈이')
cat136= 된장국얼갈이+배추국얼갈이
dict[cat[136]]= cat136

# %%
cat[137]
# Out:
# '애호박된장국'

# %%
된장국애호박= search(된장국,'애호박')
cat137= 된장국애호박
dict[cat[137]]=cat137

# %%
cat[138]
# Out:
# '시금치된장국'

# %%
된장국시금치= search(된장국,'시금치')
cat138= 된장국시금치
dict[cat[138]]= cat138

# %%
cat[139]
# Out:
# '순두부달걀탕'

# %%
달걀탕= basic('달걀탕')
달걀탕두부= search(달걀탕, '두부')

# %%
계란탕= basic('계란탕')
계란탕두부= search(계란탕,'두부')

# %%
cat139= 달걀탕두부+계란탕두부
dict[cat[139]]=cat139

# %%
cat[140]
# Out:
# '쇠고기배춧국'

# %%
배춧국고기= search(배춧국,'고기')

# %%
배추국= basic('배추국')
배추국소고기= search(배추국,'소고기')
배추국쇠고기= search(배추국, '쇠고기')

# %%
cat140= 배춧국고기+배추국소고기+배추국쇠고기
dict[cat[140]]=cat140

# %%
cat[141]
# Out:
# '쇠고기미역국'

# %%
미역국= basic('미역국') # -국수
미역국고기= search(미역국, '고기') 
cat141= 미역국고기
dict[cat[141]]= cat141

# %%
dict[cat[142]]=None
# Out:
# '미역오이냉국'

# %%
냉국= basic('냉국')
냉국오이= search(냉국,'오이')
냉국오이
미역냉국= search(냉국,'미역')
미역냉국
# Out:
# ['미역참외냉국', '미역콩나물냉국', '미역냉국수', '미역우무냉국', '미역오이된장냉국']

# %%
cat[143]
# Out:
# '김치콩나물국'

# %%
콩나물국=basic('콩나물국')
search(콩나물국, '김치')
콩나물= basic('콩나물')
콩나물김치= search(콩나물, '김치')
콩나물김치국= search(콩나물김치, '국')
콩나물김치밥= search(콩나물김치,'밥')
콩나물김치밥
# Out:
# ['콩나물김치국밥', '콩나물김치밥', '친환경돈육콩나물김치밥', '김치콩나물밥과', '김치콩나물따로국밥']

# %%
cat143= list(set(콩나물김치국)-set(콩나물김치밥))
dict[cat[143]]=cat143
cat143
# Out:
# ['김치콩나물손수제비국',
#  '콩나물김치냉국',
#  '김치콩나물수제비국',
#  '김치콩나물실파국',
#  '냉이김치콩나물얼큰국',
#  '김치콩나물해장국',
#  '콩나물김치북어국',
#  '콩나물김치두부국',
#  '콩나물김치굴국',
#  '김치콩나물두부국',
#  '콩나물김치해장국',
#  '콩나물김치수제비국',
#  '김치콩나물라면국',
#  '김치콩나물북어국',
#  '김치콩나물칼제비국',
#  '김치콩나물무국',
#  '김치콩나물국물',
#  '냉이콩나물김치된장국',
#  '김치콩나물굴국']

# %%
cat[144]
# Out:
# '함박스테이크'

# %%
함박= basic('함박')
햄버그= basic('햄버그')
함바그= basic('함바그')
햄버거= basic('햄버거')

# %%
함박스테이크= search(함박,'스테이크')
함박밥= search(함박, '밥')
함박스파게티= search(함박,'스파게티')
함박볶음= search(함박,'볶음')
함박라이스= search(함박, '라이스')

# %%
햄버그스테이크= search(햄버그,'스테이크')
햄버그밥= search(햄버그, '밥')
햄버그스파게티= search(햄버그,'스파게티')
햄버그볶음= search(햄버그,'볶음')
햄버그라이스= search(햄버그, '라이스')

# %%
함바그스테이크= search(함바그,'스테이크')
함바그밥= search(함바그, '밥')
함바그스파게티= search(함바그,'스파게티')
함바그볶음= search(함바그,'볶음')
함바그라이스= search(함바그, '라이스')

# %%
햄버거스테이크= search(햄버거,'스테이크')
햄버거밥= search(햄버거, '밥')
햄버거스파게티= search(햄버거,'스파게티')
햄버거볶음= search(햄버거,'볶음')
햄버거라이스= search(햄버거, '라이스')

# %%
cat144= list(set(함박스테이크+햄버그스테이크+함바그스테이크+햄버거스테이크)-set(함박밥+ 함박스파게티+ 함박볶음+ 함박라이스+
                                                                   햄버그밥+햄버그스파게티+햄버그볶음+햄버그라이스+
                                                                   함바그밥+함바그스파게티+함바그볶음+함바그라이스+
                                                                   햄버거밥+햄버거스파게티+햄버거볶음+햄버거라이스))

# %%
dict[cat[144]]= cat144

# %%
cat[145]
# Out:
# '표고버섯구이'

# %%
버섯= basic('버섯')
버섯구이= search(버섯,'구이')
버섯조림= search(버섯,'조림')
새송이= basic('새송이')
돈육= basic('돈육')
삼겹살= basic('삽겹살')
cat145= set(버섯구이)-set(버섯조림+새송이+돈육+삼겹살)
dict[cat[145]]= cat145

# %%
cat[146]
# Out:
# '치킨데리야끼'

# %%
치킨=basic('치킨')
데리야끼= search(치킨, '데리야끼')
우동= search(치킨, '우동')
번= search(치킨, '번')
밥= search(치킨, '밥')
샐러드= search(치킨, '샐러드')
라이스= search(치킨, '라이스')
필라프= search(치킨, '필라프')
동= search(치킨, '동')
cat146= list(set(데리야끼)-set(우동+번+밥+샐러드+라이스+필라프+동))
dict[cat[146]]=cat146

# %%
cat[147]
# Out:
# '오리고기구이'

# %%
오리= basic('오리')
오리구이= search(오리, '구이')
회오리= basic('회오리')
cat147= list(set(오리구이)-set(회오리))
dict[cat[147]]= cat147

# %%
cat[148]
# Out:
# '안심스테이크'

# %%
안심= basic('안심')
안심스테이크= search(안심, '스테이크')
cat148= set(안심스테이크)
dict[cat[148]]=cat148

# %%
cat[149]
# Out:
# '런천미트구이'

# %%
dict[cat[149]]= None

# %%
cat[151]
# Out:
# '돼지고기산적'

# %%
산적= basic('산적')
돼지= search(등심,'스테이크')
등심스테이크
밥= search(등심, '밥')
소스= search(등심,'소스')
cat150= set(등심스테이크)-set(밥+소스)
dict[cat[150]]= cat150

# %%
산적
# Out:
# ['산적고구마치즈구이',
#  '치즈산적구이',
#  '섭산적모듬볶음',
#  '하와이안산적바베큐조림',
#  '언양식산적구이',
#  '고구마치즈산적구이',
#  '꼬치산적구이',
#  '찰떡산적조림',
#  '불고기산적',
#  '떡산적야채볶음',
#  '파채갈비산적',
#  '참갈비산적구이',
#  '상큼한산적샐러드',
#  '옥수수치즈산적구이',
#  '잘재운갈비산적조림',
#  '갈비산적피망볶음',
#  '산적마요덮밥',
#  '너비아니산적조림',
#  '산적',
#  '수제오븐산적',
#  '숯불갈비산적떡조림',
#  '치즈섭산적구이',
#  '언냥산적구이',
#  '갈비산적양송이조림',
#  '허브산적바베큐조림',
#  '고기산적깻잎무쌈',
#  '모듬산적떡조림',
#  '카레파산적',
#  '눈꽃섭산적',
#  '햄꼬치산적',
#  '산적비엔나매콤덮밥',
#  '섭산적메추리알조림',
#  '꼬치산적전',
#  '두부섭산적구이',
#  '갈비산적구이',
#  '콘치즈섭산적구이',
#  '궁중고기산적조림',
#  '매운직화산적구이',
#  '고구마무스산적',
#  '직화산적메추리알조림',
#  '꽃산적구이',
#  '산적고추장볶음',
#  '갈비산적우스타조림',
#  '너비아니깻잎산적',
#  '맛살삼색산적구이',
#  '산적파채무침',
#  '깻잎산적',
#  '쇠고기산적구이',
#  '섭산적전',
#  '한입산적꼬치',
#  '콘치즈궁중산적',
#  '떡갈비산적강정',
#  '산적피망볶음',
#  '미니갈비산적',
#  '산적계란구이',
#  '쌀떡고기산적',
#  '모듬산적계란구이',
#  '납작그릴산적조림',
#  '담양갈비산적',
#  '고기산적데리야키구이',
#  '두부섭산적',
#  '고기떡산적',
#  '언양식불고기산적',
#  '섭산적조림',
#  '산적파팔레볶음',
#  '고구마치즈불닭산적',
#  '꽃산적',
#  '오색꼬지산적',
#  '섭산적콘마요브레드',
#  '미니산적조림',
#  '네모난고기산적전',
# ...

# %%
dict.keys()
# Out:
# dict_keys(['열무나물무침', '콩나물된장국', '숙주나물무침', '비름나물무침', '배추나물무침', '방풍나물무침', '냉이나물무침', '깻잎나물무침', '건취나물무침', '가지나물무침', '가죽나물무침', '돌나물물김치', '고들빼기김치', '호박잎된장국', '우거지된장국', '치킨데리야끼', '얼갈이배춧국', '애호박된장국', '시금치된장국', '순두부달걀탕', '쇠고기배춧국', '쇠고기미역국', '김치콩나물국', '함박스테이크', '표고버섯구이', '오리고기구이', '안심스테이크', '런천미트구이', '등심스테이크'])

# %%
len(cat150)
# Out:
# 44
